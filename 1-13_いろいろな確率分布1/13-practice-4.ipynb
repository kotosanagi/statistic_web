# %% [markdown]
# ***練習問題（13. いろいろな確率分布1）***
# https://bellcurve.jp/statistics/course/7882.html

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import comb
import math

# %%
# 二項分布
def binomial(k, n, p):
    ret = comb(n, k) * math.pow(p, k) * math.pow(1-p, n-k)
    return ret

# %%
# ポアソン分布
def poisson(lmd, k):
    ret = (math.pow(math.e, (-1)*lmd)) * (math.pow(lmd, k)) / (math.factorial(k))
    return ret

math.pow(2,4)
# Out:
# 16.0

# %%
# 幾何分布
def geometric(k, p):
    ret = (math.pow(1-p, k-1)) * p
    return ret

# %% [markdown]
# **★★★★問４★★★★**
#
# ある気まぐれな歌手について考える。彼は自身のコンサートでアンコールが起こっても、それに応えてもう一曲歌うのは稀で、およそ5%程度の確率でしか歌わないと言われている。彼が年間で40公演するとき、アンコールに応えて歌ってくれる公演数が3以上となる確率を求めよ。

# %% [markdown]
# k=3以上の確率なので、k=0,1,2の確率を100%から引けばよい

# %%
# ★★★★二項分布で考える場合★★★★  
# k = 0~2
n = 40
p = 0.05

ret_0 = binomial(0, n, p)
ret_1 = binomial(1, n, p)
ret_2 = binomial(2, n, p)


print("k=0:",ret_0)
print("k=1:",ret_1)
print("k=2:",ret_2)

ans = 1 - (ret_0 + ret_1 + ret_2)
print("ans:", ans)
# Out:
# k=0: 0.12851215656510312
# k=1: 0.27055190855811184
# k=2: 0.27767169562543065
# ans: 0.3232642392513544

# %%
# ★★★★ポアソン分布で考える場合★★★★
lmd = 2 # λ:np=40*0.05=2  
# k:0~2

ret_0 = poisson(lmd, 0)
ret_1 = poisson(lmd, 1)
ret_2 = poisson(lmd, 2)


print("k=0:",ret_0)
print("k=1:",ret_1)
print("k=2:",ret_2)

ans = 1 - (ret_0 + ret_1 + ret_2)
print("ans:", ans)
# Out:
# k=0: 0.1353352832366127
# k=1: 0.2706705664732254
# k=2: 0.2706705664732254
# ans: 0.3233235838169365

# %% [markdown]
# **★★★★問５★★★★**
#
# Q.自転車に乗るのが大好きな太郎君が、1日のうちに自転車に乗って転んでしまう確率は25%であるという。転んだ日から次に転ぶ日までの平均日数はどのくらいであると期待されるか。ただし、転んだ日から次に転ぶ日までの日数は幾何分布に従うものとする。
#
# A.期待値E = 1/pなので、
# 1/0.25 = 4日間
#
# ※でもそれだけじゃ面白くないので、以下で補足。
# 期待値は、日数*確率の足しあげで求められる。

# %%
MAX_DAYS = 50
p = 0.25
sum = 0
for i in range(MAX_DAYS+1):
    px = geometric(i, p) # 幾何分布を計算する
    sum += i * px # この合計が期待値
    print(f'{i}日の確率は{px:.8f}である。\t合計は{sum:.8f}である。')
# Out:
# 0日の確率は0.33333333である。	合計は0.00000000である。
# 1日の確率は0.25000000である。	合計は0.25000000である。
# 2日の確率は0.18750000である。	合計は0.62500000である。
# 3日の確率は0.14062500である。	合計は1.04687500である。
# 4日の確率は0.10546875である。	合計は1.46875000である。
# 5日の確率は0.07910156である。	合計は1.86425781である。
# 6日の確率は0.05932617である。	合計は2.22021484である。
# 7日の確率は0.04449463である。	合計は2.53167725である。
# 8日の確率は0.03337097である。	合計は2.79864502である。
# 9日の確率は0.02502823である。	合計は3.02389908である。
# 10日の確率は0.01877117である。	合計は3.21161079である。
# 11日の確率は0.01407838である。	合計は3.36647296である。
# 12日の確率は0.01055878である。	合計は3.49317837である。
# 13日の確率は0.00791909である。	合計は3.59612651である。
# 14日の確率は0.00593932である。	合計は3.67927694である。
# 15日の確率は0.00445449である。	合計は3.74609424である。
# 16日の確率は0.00334087である。	合計は3.79954808である。
# 17日の確率は0.00250565である。	合計は3.84214412である。
# 18日の確率は0.00187924である。	合計は3.87597038である。
# 19日の確率は0.00140943である。	合計は3.90274950である。
# 20日の確率は0.00105707である。	合計は3.92389091である。
# 21日の確率は0.00079280である。	合計は3.94053978である。
# 22日の確率は0.00059460である。	合計は3.95362103である。
# 23日の確率は0.00044595である。	合計は3.96387791である。
# 24日の確率は0.00033446である。	合計は3.97190504である。
# 25日の確率は0.00025085である。	合計は3.97817624である。
# 26日の確率は0.00018814である。	合計は3.98306777である。
# 27日の確率は0.00014110である。	合計は3.98687752である。
# 28日の確率は0.00010583である。	合計は3.98984066である。
# 29日の確率は0.00007937である。	合計は3.99214239である。
# 30日の確率は0.00005953である。	合計は3.99392821である。
# 31日の確率は0.00004465である。	合計は3.99531222である。
# 32日の確率は0.00003348である。	合計は3.99638371である。
# 33日の確率は0.00002511である。	合計は3.99721245である。
# 34日の確率は0.00001883である。	合計は3.99785283である。
# 35日の確率は0.00001413である。	合計は3.99834724である。
# 36日の確率は0.00001059である。	合計は3.99872865である。
# 37日の確率は0.00000795である。	合計は3.99902265である。
# 38日の確率は0.00000596である。	合計は3.99924911である。
# 39日の確率は0.00000447である。	合計は3.99942342である。
# 40日の確率は0.00000335である。	合計は3.99955751である。
# 41日の確率は0.00000251である。	合計は3.99966059である。
# 42日の確率は0.00000189である。	合計は3.99973979である。
# 43日の確率は0.00000141である。	合計は3.99980060である。
# 44日の確率は0.00000106である。	合計は3.99984727である。
# 45日の確率は0.00000080である。	合計は3.99988306である。
# 46日の確率は0.00000060である。	合計は3.99991051である。
# 47日の確率は0.00000045である。	合計は3.99993154である。
# 48日の確率は0.00000034である。	合計は3.99994765である。
# 49日の確率は0.00000025である。	合計は3.99995998である。
# 50日の確率は0.00000019である。	合計は3.99996942である。
